# %%
using Distributions, HypothesisTests, Gadfly

# %%
β = Beta(8, 17)
# Out:
# Beta(α=8.0, β=17.0)

# %%
cdf(β, .3)
# Out:
# 0.43532599006656864

# %% [markdown]
# # Power Tests

# %% [markdown]
# # Example 8.5-2

# %%
ccdf(Normal(60, sqrt(100 / 25)), 62)
# Out:
# 0.15865525393145707

# %%
ccdf(Normal(61, sqrt(100 / 25)), 62)
# Out:
# 0.30853753872598694

# %%
ccdf(Normal(62, sqrt(100 / 25)), 62)
# Out:
# 0.5

# %% [markdown]
# # Exercise 8.5-1

# %%
cdf(Normal(25, sqrt(9 / 4)), 22.5)
# Out:
# 0.0477903522728147

# %%
potatoes = [21.24, 24.81, 23.62, 26.82];

# %%
ci(OneSampleTTest(potatoes, 22.5), 0.0477903522728147)
# Out:
# (20.34319907323983,27.901800926760174)

# %%
cdf(Normal(25, sqrt(9 / 4)), mean(potatoes))
# Out:
# 0.2792738583819836

# %% [markdown]
# # Exercise 8.5-2

# %% [markdown]
# # b)

# %%
cdf(Normal(530, sqrt(8100/36)), 510.77)
# Out:
# 0.0999213231133827

# %% [markdown]
# # c)

# %%
cdf(Normal(510.77, sqrt(8100/36)), 510.77)
# Out:
# 0.5

# %%
plot(x -> cdf(Normal(x, sqrt(8100/36)), 510.77), 500, 530)
# Out:
# Plot(...)

# %% [markdown]
# # e)

# %%
cdf(Normal(530, sqrt(8100/36)), 507.35)
# Out:
# 0.06552171208891672

# %%
cdf(Normal(530, sqrt(8100/36)), 497.45)
# Out:
# 0.01500342297373218

# %% [markdown]
# # Exercise 8.5-5

# %%
alfalfa = Normal(1.5, sqrt(0.09))
# Out:
# Normal(μ=1.5, σ=0.3)

# %%
plot(x -> pdf(alfalfa, x), 0, 3)
# Out:
# Plot(...)

# %%
quantile(alfalfa, .05)
# Out:
# 1.0065439119145583

# %%
1.645^2 * .09
# Out:
# 0.24354225

# %%
1.5 +(0.24354225 * 1.7)
# Out:
# 1.9140218249999998

# %%
1.5 +(0.24354225 * 1.7) / (1 + 1.645^2 * .09)
# Out:
# 1.8329374816175323

# %%
1/((-1.645)(.3)(1.8329374816175323 + 1.7))
# Out:
# -0.5735574044029274
